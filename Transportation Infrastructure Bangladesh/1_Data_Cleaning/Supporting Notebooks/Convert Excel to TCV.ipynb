# %%
# Put this file in the same folder as the tcv and the updated cleaned excel file of the roads

# %% [markdown]
# ### Instructions
# Put this file in the same folder as the tcv file and cleaned excel file of the roads (BMMS_overview.xlsx)

# %%
# Import the panda library 
import pandas as pd

# %%
# Name the file 
data = "excelroad_v1.xlsx" # check the file name of the latest version of the uploaded road excel file

# %%
# Read the file 
data1 = pd.read_excel(data, index_col = 0)

# %%
# Display the table 
data1.head()
# Out:
#       lrp1       lat1       lon1    lrp2       lat2       lon2   lon2.1  \
# road
# N100  LRPS  23.706028  90.443333   LRPSa  23.702917  90.450417    LRPSb
# N101  LRPS  23.454139  91.212861   LRPSa  23.461889  91.212000   LRP001
# N102  LRPS  23.478972  91.118194   LRPSa  23.481583  91.116777    LRPSb
# N103  LRPS  23.957028  91.115528  LRP001  23.961917  91.113611  LRP001a
# N104  LRPS  23.009667  91.399416   LRPSa  23.009278  91.395250   LRP001
#
#       Unnamed: 8  Unnamed: 9 Unnamed: 10  ...  Unnamed: 3654  Unnamed: 3655  \
# road                                      ...
# N100   23.702778   90.450472      LRP001  ...      90.954167        LRP439d
# N101   23.462944   91.211806     LRP001a  ...            NaN            NaN
# N102   23.486666   91.113361      LRP001  ...            NaN            NaN
# N103   23.967666   91.111889      LRP002  ...            NaN            NaN
# N104   23.009306   91.389805     LRP001a  ...            NaN            NaN
#
# ...

# %%
# Convert to tcv 
data1.to_csv("_roads.tcv", sep="\t")
